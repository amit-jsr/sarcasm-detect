# %% [markdown]
# **Its a notebook of BERT along with LSTM layer**

# %%
# !nvidia-smi
# Out:
# Wed Jul  7 18:44:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Import Library

# %%
# !pip install -q tensorflow-text
# !pip install -q tf-models-official
# !pip install -q tfds-nightly
# Out:
#      |████████████████████████████████| 4.3MB 15.0MB/s
#      |████████████████████████████████| 1.6MB 15.5MB/s
#      |████████████████████████████████| 686kB 49.3MB/s
#      |████████████████████████████████| 215kB 52.3MB/s
#      |████████████████████████████████| 61kB 8.6MB/s
#      |████████████████████████████████| 38.2MB 1.2MB/s
#      |████████████████████████████████| 102kB 12.8MB/s
#      |████████████████████████████████| 358kB 44.5MB/s
#      |████████████████████████████████| 645kB 40.0MB/s
#      |████████████████████████████████| 1.2MB 47.0MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
#      |████████████████████████████████| 3.9MB 14.7MB/s

# %%
import os
import shutil
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow_datasets as tfds
from official.nlp import optimization
import tensorflow_addons as tfa
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

tf.get_logger().setLevel('ERROR')

# %%
#Connect to the TPU worker
"""
if os.environ['COLAB_TPU_ADDR']:
  cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
  tf.config.experimental_connect_to_cluster(cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(cluster_resolver)
  strategy = tf.distribute.TPUStrategy(cluster_resolver)
  print('Using TPU')
elif tf.test.is_gpu_available():
  strategy = tf.distribute.MirroredStrategy()
  print('Using GPU')
else:
  raise ValueError('Running on CPU is not recommended.')"""
# Out:
# "\nif os.environ['COLAB_TPU_ADDR']:\n  cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')\n  tf.config.experimental_connect_to_cluster(cluster_resolver)\n  tf.tpu.experimental.initialize_tpu_system(cluster_resolver)\n  strategy = tf.distribute.TPUStrategy(cluster_resolver)\n  print('Using TPU')\nelif tf.test.is_gpu_available():\n  strategy = tf.distribute.MirroredStrategy()\n  print('Using GPU')\nelse:\n  raise ValueError('Running on CPU is not recommended.')"

# %%
print("TF Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("Hub version: ", hub.__version__)
print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# TF Version:  2.5.0
# Eager mode:  True
# Hub version:  0.12.0
# GPU is available

# %% [markdown]
# ### Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train_df=pd.read_csv('/content/drive/MyDrive/sarcasm/reddit/Reddit-train.csv')
valid_df=pd.read_csv('/content/drive/MyDrive/sarcasm/reddit/Reddit-valid.csv')
test_df=pd.read_csv('/content/drive/MyDrive/sarcasm/reddit/Reddit-test.csv')

# %%
train_df.shape, valid_df.shape, test_df.shape
# Out:
# ((24937, 4), (3117, 4), (3118, 4))

# %%
#Change Column heere
column_='comment'

# %%
import numpy as np
train_df[column_].replace('', np.nan, inplace=True)
train_df[column_].replace('nan', np.nan, inplace=True)
train_df.dropna(subset=[column_], inplace=True)

# %%
train_df[column_]=train_df[column_].astype(str)

# %%
train_data = tf.data.Dataset.from_tensor_slices((train_df[column_].values, train_df['label'].values))
valid_data = tf.data.Dataset.from_tensor_slices((valid_df[column_].values, valid_df['label'].values))

# %% [markdown]
# ### Model Build

# %%
bert_preprocess_model_handle = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"
bert_model_handle = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3"

# %%
os.environ["TFHUB_MODEL_LOAD_FORMAT"]="UNCOMPRESSED"

# %%
def build_model():
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
  preprocessing_layer = hub.KerasLayer(bert_preprocess_model_handle, name='preprocessing')
  encoder_inputs = preprocessing_layer(text_input)
  encoder = hub.KerasLayer(bert_model_handle, trainable=True, name='BERT_encoder')
  outputs = encoder(encoder_inputs)
  net = outputs['sequence_output']
  net = tf.keras.layers.Dropout(0.3)(net)
  net = tf.keras.layers.LSTM(768, name="LSTM1")(net)
  net = tf.keras.layers.Dense(1, activation="sigmoid", name="output")(net)
  return tf.keras.Model(text_input, net)

# %% [markdown]
# ### Model-1

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               [(None,)]            0
# __________________________________________________________________________________________________
# preprocessing (KerasLayer)      {'input_word_ids': ( 0           text[0][0]
# __________________________________________________________________________________________________
# BERT_encoder (KerasLayer)       {'pooled_output': (N 109482241   preprocessing[0][0]
#                                                                  preprocessing[0][1]
#                                                                  preprocessing[0][2]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 768)     0           BERT_encoder[0][14]
# __________________________________________________________________________________________________
# LSTM1 (LSTM)                    (None, 768)          4721664     dropout[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            769         LSTM1[0][0]
# ==================================================================================================
# Total params: 114,204,674
# Trainable params: 114,204,673
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model=model, show_shapes=True, dpi=60 )

# %% [markdown]
# ### Set Parameters

# %%
epochs = 20
steps_per_epoch = tf.data.experimental.cardinality(train_data).numpy()
num_train_steps = steps_per_epoch * epochs
num_warmup_steps = int(0.1*num_train_steps)

init_lr = 2e-5
opt = optimization.create_optimizer(init_lr=init_lr, num_train_steps=num_train_steps, num_warmup_steps=num_warmup_steps, optimizer_type='adamw')

# %%
model.compile(optimizer=opt,
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
train_data = train_data.shuffle(BUFFER_SIZE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
valid_data = valid_data.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_keras_model.h5", save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=1, restore_best_weights=True)

# %%
history = model.fit(x=train_data, epochs=epochs, validation_data=valid_data, callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/10
# 780/780 [==============================] - 301s 361ms/step - loss: 0.6742 - binary_accuracy: 0.5831 - val_loss: 0.6297 - val_binary_accuracy: 0.6679
# Epoch 2/10
# 780/780 [==============================] - 281s 360ms/step - loss: 0.5964 - binary_accuracy: 0.6896 - val_loss: 0.5540 - val_binary_accuracy: 0.7228
# Epoch 3/10
# 780/780 [==============================] - 282s 361ms/step - loss: 0.5452 - binary_accuracy: 0.7269 - val_loss: 0.5103 - val_binary_accuracy: 0.7472
# Epoch 4/10
# 780/780 [==============================] - 281s 360ms/step - loss: 0.5085 - binary_accuracy: 0.7537 - val_loss: 0.4686 - val_binary_accuracy: 0.7764
# Epoch 5/10
# 780/780 [==============================] - 281s 360ms/step - loss: 0.4795 - binary_accuracy: 0.7733 - val_loss: 0.4366 - val_binary_accuracy: 0.7947
# Epoch 6/10
# 780/780 [==============================] - 281s 360ms/step - loss: 0.4426 - binary_accuracy: 0.7980 - val_loss: 0.3859 - val_binary_accuracy: 0.8332
# Epoch 7/10
# 780/780 [==============================] - 281s 360ms/step - loss: 0.4025 - binary_accuracy: 0.8209 - val_loss: 0.3531 - val_binary_accuracy: 0.8466
# Epoch 8/10
# 780/780 [==============================] - 280s 360ms/step - loss: 0.3555 - binary_accuracy: 0.8475 - val_loss: 0.3105 - val_binary_accuracy: 0.8755
# Epoch 9/10
# 780/780 [==============================] - 281s 361ms/step - loss: 0.3020 - binary_accuracy: 0.8730 - val_loss: 0.2534 - val_binary_accuracy: 0.9089
# Epoch 10/10
# 780/780 [==============================] - 282s 361ms/step - loss: 0.2404 - binary_accuracy: 0.9029 - val_loss: 0.2222 - val_binary_accuracy: 0.9301

# %% [markdown]
# ### Training

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])
  plt.show()

# %%
plot_graphs(history, 'binary_accuracy')

# %%
plot_graphs(history, 'loss')

# %% [markdown]
# ### Testing-1

# %%
test_data = tf.data.Dataset.from_tensor_slices((test_df[column_].values, test_df['label'].values))

# %%
eval=model.evaluate(valid_data, verbose=1)

# %%
predicted = model.predict([test_df[coulmn_]])

# %%
pred=[1 if p >=0.5 else 0 for p in predicted]

# %%
from pandas import DataFrame
pred_df = DataFrame (pred,columns=['pred_label'])

# %%
true_label = test_df["label"]

# %%
true_label.sum()

# %%
sum(pred)

# %%
test_df

# %%
pred_df

# %% [markdown]
# Reddit-LSTM-comment

# %%
from sklearn.metrics import precision_score,recall_score,f1_score, accuracy_score
accuracy_score(true_label,pred_df),precision_score(true_label,pred_df),recall_score(true_label,pred_df),f1_score(true_label,pred_df)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
matrix = confusion_matrix(true_label, pred_df)

print("Confusion Matrix:\n {}".format(matrix))

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(true_label, pred_df)

def plot_roc_curve(fpr, tpr, label=None):
  plt.plot(fpr, tpr, linewidth=2, label=label)
  plt.plot([0, 1], [0, 1], 'k--')

plot_roc_curve(fpr, tpr)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(true_label, pred_df)
